# %% [markdown]
# # Casting Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Table of Data

# %%
#Reading Data from csv file
df = pd.read_csv('Data.csv')
df
# Out:
#              Origin    Type  Fineness modulus (FM)  Bulk density(kg/m3)  \
# 0          Melamchi    Fine                  3.022            1590.0175
# 1          Melamchi  Coarse                  4.721            1883.8940
# 2          Sunkoshi    Fine                  3.561            1576.4122
# 3          Sunkoshi  Coarse                  5.237            1877.5450
# 4         Jhaukhel1  Coarse                  4.307            1627.4325
# 5         Jhaukhel2  Coarse                  4.684            1788.6564
# 6         Jhaukhel3  Coarse                  4.818            1777.4698
# 7           Shakhu1  Coarse                  4.489            1741.4910
# 8           Shakhu2    Fine                  4.406            1751.7707
# 9           Shakhu3  Coarse                  4.950            1708.3846
# 10  Dhading(Single)  Coarse                  4.329            1792.9640
# 11  Dhading(Double)    Fine                  3.994            1755.3988
# ...

# %% [markdown]
# ## Scatter plot

# %%
#This visualize relation of each variable with other varible assuming two class Coarse and Fine
sns.set(style="ticks")
sns.pairplot(df, hue="Type")

# %% [markdown]
# ## General summary of the Table

# %%
df.describe()
# Out:
#        Fineness modulus (FM)  Bulk density(kg/m3)  Specifi Gravity  \
# count              18.000000            18.000000        18.000000
# mean                4.321000          1730.648567         2.594728
# std                 0.681387           109.246161         0.196572
# min                 3.022000          1522.595000         2.146000
# 25%                 3.869500          1635.746250         2.478250
# 50%                 4.367500          1753.584750         2.618550
# 75%                 4.711750          1791.887100         2.688500
# max                 5.735000          1883.894000         3.014000
#
#             Cube1     Cube 2       Cube3        Mean    Cube1.1      Cube2  \
# count   18.000000  18.000000   18.000000   18.000000  18.000000  18.000000
# mean    33.027778  33.638889   33.000000   33.222222  27.222222  28.805556
# std     25.034372  18.835047   27.546752   22.973841  18.926500  14.742036
# ...

# %% [markdown]
# ## Correlation of each variable with other

# %%
df.corr()
# Out:
#                        Fineness modulus (FM)  Bulk density(kg/m3)  \
# Fineness modulus (FM)               1.000000             0.178923
# Bulk density(kg/m3)                 0.178923             1.000000
# Specifi Gravity                     0.141833             0.131838
# Cube1                               0.107551             0.335436
# Cube 2                              0.073935             0.261196
# Cube3                               0.121894             0.327136
# Mean                                0.107990             0.323972
# Cube1.1                             0.091962             0.300434
# Cube2                               0.103027             0.274914
# Cube3.1                             0.173421             0.292952
# Mean.1                              0.129809             0.304787
# C                                   0.009313             0.149507
# S                                   0.105626             0.287606
#
# ...
